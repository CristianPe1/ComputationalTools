# %% [markdown]
# Se deben crear una función que reciba el tamaño N y el número de repeticiones NREP para retornar el tiempo promedio y la desviación estándar de ese tiempo promedio que se demora en resolver un sistema de la forma A x = b
# Solamente se debe medir el tiempo que se toma en resolver el sistema, no en crear la matriz o el vector.
# Se debe graficar este tiempo promedio (y la desviación estándar como barras de error), normalizado por el obtenido para N=100, en función del tamaño del sistema. Los valores a explorar son N = 10, 20, 50, 80, 100, 200, 500, 700, 1000, 2000, 5000, 8000, 10000, 20000, 50000.

# %%
import time 
from scipy import linalg
import numpy as np
import matplotlib.pyplot as plt

# %%
def execution_time(N,NREPS): 

    #tm = np.arange(NREPS,dtype=)
    tm = np.zeros(NREPS)

    def sys(N):
      
        A = np.random.rand(N, N)
        b = np.random.rand(N)
        start = time.perf_counter()
        linalg.solve(A,b)
        end = time.perf_counter()
        print(f"{end},{start}")
        print(f"{end - start}")
        return end - start
        
    
    for i in range(NREPS):
        
        tm[i] = sys(N)

    print(tm)
    mean = np.mean(tm)
    std = np.std(tm)

    return mean,std

execution_time = np.vectorize(execution_time)

# %%
def grafica_error(x,y,y_err):

    fig,ax = plt.subplots(figsize=(10, 6))
    fig.suptitle(" Tiempo de resolución vs Numero de semilla ")


    plt.errorbar(x, y, yerr=y_err,fmt = "yo-")#,ecolor="r")  

    plt.xlabel("Numero de semilla")
    plt.ylabel('#N')
    
    plt.xscale("log")
    plt.yscale("log")

    plt.savefig("Figura.pdf")

# %%
NREPS = 10
N = [10, 20, 50, 80, 100, 200, 500, 700, 1000]#, 2000, 5000, 8000, 10000, 20000]#, 50000]


means,stds = execution_time(N,NREPS)

grafica_error(N,means,stds)
# Out:
# 320.067291073,320.066968487
# 0.0003225859999815839
# 320.077352415,320.07714347
# 0.00020894499999712934
# 320.079012186,320.07885517
# 0.00015701600000284088
# 320.079551732,320.079444223
# 0.00010750900003131392
# 320.079684149,320.079610835
# 7.331400001930888e-05
# 320.079842679,320.079744163
# 9.851600003685235e-05
# 320.080000804,320.079914749
# 8.60549999970317e-05
# 320.080172676,320.080066656
# 0.00010602000003245848
# 320.080321364,320.080238763
# 8.260099997414727e-05
# 320.080472608,320.08038768
# 8.492799997839029e-05
# [3.22586e-04 2.08945e-04 1.57016e-04 1.07509e-04 7.33140e-05 9.85160e-05
#  8.60550e-05 1.06020e-04 8.26010e-05 8.49280e-05]
# 320.081427817,320.081277442
# 0.0001503750000324544
# 320.08162062,320.081516035
# 0.0001045850000309656
# 320.081806898,320.081695166
# 0.00011173200005032413
# 320.081982004,320.081884587
# 9.741700000631681e-05
# 320.09337338,320.082058558
# 0.011314821999974356
# 320.09361328,320.093495295
# 0.00011798499997439649
# 320.093764698,320.093674969
# 8.972899996706474e-05
